# %%
lll
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e8666c30fa3f> in <cell line: 0>()
# ----> 1 lll
#
# NameError: name 'lll' is not defined
