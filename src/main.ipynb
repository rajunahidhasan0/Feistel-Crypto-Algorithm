# %%
# main.py
from feistel_cipher import encrypt_block, decrypt_block

# Example plaintext (32-bit)
plaintext = 0x12345678
key = 0xA1B2C3D4  # 32-bit master key

# Encrypt
ciphertext = encrypt_block(plaintext, key)
print(f"Ciphertext: {hex(ciphertext)}")

# Decrypt
decrypted = decrypt_block(ciphertext, key)
print(f"Decrypted: {hex(decrypted)}")

# Check if decryption is successful
assert decrypted == plaintext, "Decryption failed!"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6e83721dca3a> in <cell line: 0>()
#       1 # main.py
# ----> 2 from feistel_cipher import encrypt_block, decrypt_block
#       3
#       4 # Example plaintext (32-bit)
#       5 plaintext = 0x12345678
#
# ModuleNotFoundError: No module named 'feistel_cipher'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
