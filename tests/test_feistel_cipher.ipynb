# %%
from feistel_cipher import encrypt_block, decrypt_block

def test_feistel_cipher():
    plaintext = 0x12345678
    key = 0xA1B2C3D4
    ciphertext = encrypt_block(plaintext, key)
    decrypted = decrypt_block(ciphertext, key)
    assert decrypted == plaintext, "Decryption failed!"

if __name__ == "__main__":
    test_feistel_cipher()
    print("All tests passed!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4af6ca6dc2f5> in <cell line: 0>()
# ----> 1 from feistel_cipher import encrypt_block, decrypt_block
#       2
#       3 def test_feistel_cipher():
#       4     plaintext = 0x12345678
#       5     key = 0xA1B2C3D4
#
# ModuleNotFoundError: No module named 'feistel_cipher'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
